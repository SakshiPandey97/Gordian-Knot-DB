# %%
import xlrd
import xlsxwriter
import re
from itertools import takewhile
number=0
position=[]
rSASA=[]
start=[]
end=[]

dtf='Influenza_netsurf'
def column_len(sheet, index):
    col_values = sheet.col_values(index)
    col_len = len(col_values)
    for _ in takewhile(lambda x: not x, reversed(col_values)):
        col_len -= 1
    return col_len

name1=str(dtf)+".xlsx"                                    
wb2 = xlrd.open_workbook(name1) 
sheet = wb2.sheet_by_index(number)

name2="Influenza.xlsx"                                    
wb3 = xlrd.open_workbook(name2) 
sheet1 = wb3.sheet_by_index(0)

for i in range(0, sheet.nrows):
    row = sheet.row_slice(i)
    rSASA.append(row[3].value)
rSASA.pop(0)
for i in range(0, sheet1.nrows):
    row = sheet1.row_slice(i)
    start.append(row[2].value)
for i in range(0, sheet1.nrows):
    row = sheet1.row_slice(i)
    end.append(row[3].value)

start.pop(0)
end.pop(0)
avg_SASA=[]
for i in start:
    i=float(i)
    i=int(i)
    sum_rSASA=rSASA[i-1]+rSASA[i]+rSASA[i+1]
    avg=sum_rSASA/3
    avg=round(avg,3)
    avg_SASA.append(avg)
    
    
    
for h in avg_SASA:
    print(h)
# Out:
# 0.145
# 0.145
# 0.467
# 0.467
# 0.467
# 0.476
# 0.408
# 0.292
# 0.353
# 0.419
# 0.419
# 0.419
# 0.419
# 0.446
# 0.693
# 0.252
# 0.252
# 0.333
# 0.333
# 0.346
# 0.773
# 0.773
# 0.361
# 0.123
# 0.123
# 0.123
# 0.324
# 0.324
# 0.324
# 0.324
# 0.324
# 0.154
# 0.352
# 0.352
# 0.326
# 0.326
# 0.571
# 0.571
# 0.571
# 0.571
# 0.571
# 0.571
# 0.571
# 0.571
# 0.571
# 0.571
# 0.571
# 0.571
# 0.571
# 0.571
# 0.571
# 0.571
# 0.571
# 0.261
# 0.261
# 0.185
# 0.185
# 0.185
# 0.278
# 0.278
# 0.426
# 0.426
# 0.426
# 0.426
# 0.426
# 0.426
# 0.426
# 0.426
# 0.426
# 0.426
# 0.49
# 0.49
# 0.49
# 0.404
# 0.109
# 0.109
# 0.338
# 0.338
# 0.657
# 0.327
# 0.289
# 0.228
# 0.431
# 0.431
# 0.431
# 0.256
# 0.333
# 0.1
# 0.422
# 0.085
# 0.085
# 0.213
# 0.213
# 0.095
# 0.78
# 0.333
# 0.357
# 0.357
# 0.357
# 0.282
# 0.282
# 0.282
# 0.282
# 0.348
# 0.348
# 0.348
# 0.282
# 0.256
# 0.256
# 0.347
# 0.347
# 0.262
# 0.262
# 0.262
# 0.29
# 0.431
# 0.1
# 0.1
# 0.375
# 0.375
# 0.329
# 0.329
# 0.329
# 0.37
# 0.37
# 0.37
# ...

# %%
import xlrd
import xlsxwriter
import re
from itertools import takewhile
number=0
position=[]
rSASA=[]
start=[]
end=[]

dtf='CoVspikeNetSurfP'
def column_len(sheet, index):
    col_values = sheet.col_values(index)
    col_len = len(col_values)
    for _ in takewhile(lambda x: not x, reversed(col_values)):
        col_len -= 1
    return col_len

name1=str(dtf)+".xlsx"                                    
wb2 = xlrd.open_workbook(name1) 
sheet = wb2.sheet_by_index(number)

name2="main53.xlsx"                                    
wb3 = xlrd.open_workbook(name2) 
sheet1 = wb3.sheet_by_index(0)

for i in range(0, sheet.nrows):
    row = sheet.row_slice(i)
    rSASA.append(row[3].value)
rSASA.pop(0)
for i in range(0, sheet1.nrows):
    row = sheet1.row_slice(i)
    start.append(row[2].value)
for i in range(0, sheet1.nrows):
    row = sheet1.row_slice(i)
    end.append(row[3].value)
start.pop(0)
end.pop(0)
avg_SASA=[]
for i in start:
    i=float(i)
    i=int(i)
    #print("+++++++++++++++++++++++++++++++++++")
    #print(i)
    #print(rSASA[i-1])
    #print("+++++++++++++++++++++++++++++++++++")
    sum_rSASA=rSASA[i-1]+rSASA[i]+rSASA[i+1]
    avg=sum_rSASA/3

    avg=round(avg,3)
    #print(avg)
    avg_SASA.append(avg)
    
    
for h in avg_SASA:
    print(h)
# Out:
# 0.513
# 0.184
# 0.238
# 0.469
# 0.391
# 0.324
# 0.504
# 0.504
# 0.703
# 0.279
# 0.527
# 0.304
# 0.148
# 0.16
# 0.423
# 0.365
# 0.433
# 0.212
# 0.212
# 0.212
# 0.212
# 0.212
# 0.874
# 0.241
# 0.241
# 0.332
# 0.332
# 0.219
# 0.202
# 0.599
# 0.599
# 0.599
# 0.551
# 0.551
# 0.305
# 0.194
# 0.194
# 0.304
# 0.304
# 0.315
# 0.513
# 0.513
# 0.12
# 0.747
# 0.083
# 0.342
# 0.547
# 0.179
# 0.647
# 0.647
# 0.331
# 0.331
# 0.114
# 0.114
# 0.502
# 0.502
# 0.502
# 0.502
# 0.502
# 0.502
# 0.502
# 0.502
# 0.502
# 0.502
# 0.502
# 0.502
# 0.502
# 0.502
# 0.49
# 0.544
# 0.35
# 0.077
# 0.077
# 0.077
# 0.077
# 0.077
# 0.077
# 0.077
# 0.15
# 0.15
# 0.241
# 0.241
# 0.241
# 0.508
# 0.508
# 0.017
# 0.017
# 0.017
# 0.077
# 0.235
# 0.335
# 0.444
# 0.444
# 0.444
# 0.444
# 0.444
# 0.444
# 0.444
# 0.444
# 0.444
# 0.444
# 0.444
# 0.209
# 0.112
# 0.375
# 0.362
# 0.362
# 0.362
# 0.349
# 0.349
# 0.349
# 0.349
# 0.349
# 0.349
# 0.076
# 0.554
# 0.554
# 0.554
# 0.193
# 0.387
# 0.387
# 0.387
# 0.415
# 0.247
# 0.469
# ...

# %%
#DEPTH PROGRAM
import xlrd
import xlsxwriter
import re
from itertools import takewhile
number=0
position=[]
rSASA=[]
start=[]
end=[]
numo=4
dtf='1zv8DEPTH'
def column_len(sheet, index):
    col_values = sheet.col_values(index)
    col_len = len(col_values)
    for _ in takewhile(lambda x: not x, reversed(col_values)):
        col_len -= 1
    return col_len

name1=str(dtf)+".xlsx"                                    
wb2 = xlrd.open_workbook(name1) 
sheet = wb2.sheet_by_index(numo)

name2="main55.xlsx"                                    
wb3 = xlrd.open_workbook(name2) 
sheet1 = wb3.sheet_by_index(0)
res_num=[]
for i in range(0, sheet.nrows):
    row = sheet.row_slice(i)
    rSASA.append(row[3].value)
    res_num.append(row[1].value)
rSASA.pop(0)
res_num.pop(0)

for i in range(0, sheet1.nrows):
    row = sheet1.row_slice(i)
    start.append(row[2].value)
start.pop(0)
#start.pop(4386)
#start.pop(4385)
#print(start)
avg_SASA=[]
cnt=0
for i in res_num:
    inds=res_num.index(i)
    res_num[inds]=int(i)
for i in res_num:
    inds=res_num.index(i)
    res_num[inds]=int(i)

for i in start:
    inds=start.index(i)
    start[inds]=int(float(i))
      
for i in start:
    if ((i in res_num) and (i+1 in res_num) and (i+2 in res_num)):
        ind=res_num.index(i)
        ind=float(ind)
        ind=int(ind)
        if i == 45:
            avg_SASA.append("NONE")
            continue
        sum_rSASA=rSASA[ind]+rSASA[ind+1]+rSASA[ind+2]+rSASA[ind+3]+rSASA[ind+4]
        avg=sum_rSASA/3
        avg=round(avg,3)
        avg_SASA.append(avg)
    else:
        avg_SASA.append("NONE")
    
    
    
for h in avg_SASA:
    print(h)
# Out:
# NONE
# NONE
# NONE
# NONE
# NONE
# NONE
# NONE
# NONE
# NONE
# NONE
# NONE
# NONE
# NONE
