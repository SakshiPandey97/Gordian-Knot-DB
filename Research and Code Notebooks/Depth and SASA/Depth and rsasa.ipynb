# %%
#prog to determine if accessible according to depth or not

#1 to 4 in depth is accessible
#7 to 14 in depth is buried
#4 to 7 in depth is a maybe

import xlrd
import xlsxwriter 

wb = xlrd.open_workbook("LatestTripeptides_Serine_prime.xlsx") 
sheet = wb.sheet_by_index(0)

#workbook = xlsxwriter.Workbook("TripepAccessClassOutput.xlsx")
#worksheet = workbook.add_worksheet()
def column_len(sheet, index):
    col_values = sheet.col_values(index)
    col_len = len(col_values)
    for _ in takewhile(lambda x: not x, reversed(col_values)):
        col_len -= 1
    return col_len
tr=[]
acs=[]
rSA=[]
val=[]

#worksheet.write(0, 0, "Protease")
#worksheet.write(0, 1, "Access")
row=1
for i in range(0, sheet.nrows):
    row = sheet.row_slice(i)
    rSA.append(row[6].value)
    val.append(row[10].value)
val.pop(0)
rSA.pop(0)
val.pop(1179)
val.pop(1178)
print(val)
for i in val:

    ind=val.index(i)
    print(ind)
    newrs=float(rSA[ind])  
    if i == "NONE":
        if newrs>0.3:
            acs.append("rSASA")
            continue
        elif newrs<0.3:
            acs.append("Neither")
            continue
    
     
    
    else:
        i=float(i)
        if (i>=1) and (i<=5) and (newrs>=0.3):
            acs.append("Both")
        elif (i>=7) and (i<=14) and (newrs>=0.3):
            acs.append("rSASA")
        elif (i>5) and (i<7) and (newrs>=0.3):
            acs.append("rSASA and Maybe Depth")
        elif (i>=1) and (i<=5) and (newrs<0.3):
            acs.append("depth")
        elif (i>=7) and (i<=14) and (newrs<0.3):
            acs.append("Neither")
        elif (i>5) and (i<7) and (newrs<0.3):
            acs.append("Maybe Depth")
        else:
            acs.append("idk")




for i in acs:
    print(i)
# Out:
# ['NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 5.538666666666667, 5.7796666666666665, 5.7796666666666665, 5.7796666666666665, 5.7796666666666665, 5.7796666666666665, 5.7796666666666665, 5.7796666666666665, 7.975333333333334, 9.603333333333333, 6.047, 6.4110000000000005, 6.4110000000000005, 6.4110000000000005, 6.4110000000000005, 6.4110000000000005, 6.4110000000000005, 4.1690000000000005, 3.9499999999999997, 3.9499999999999997, 3.9499999999999997, 3.9499999999999997, 4.277666666666667, 4.277666666666667, 4.330333333333333, 3.966666666666667, 4.091, 4.091, 4.091, 4.091, 4.091, 4.091, 4.091, 6.195666666666667, 3.8713333333333337, 4.649666666666667, 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE', 'NONE'
# ...
